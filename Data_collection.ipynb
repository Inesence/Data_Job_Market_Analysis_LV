# %% [markdown]
# # Analysis of Data Job Market in Latvia
# ## Data Collection and preparation

# %% [markdown]
# ### 0.Setting up Virtual Environment

# %%
# !pip install virtualenv
# !virtualenv myenv
# Out:
# Requirement already satisfied: virtualenv in c:\users\ernes\anaconda3\lib\site-packages (20.23.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in c:\users\ernes\anaconda3\lib\site-packages (from virtualenv) (0.3.6)
# Requirement already satisfied: platformdirs<4,>=3.2 in c:\users\ernes\anaconda3\lib\site-packages (from virtualenv) (3.5.1)
# Requirement already satisfied: filelock<4,>=3.11 in c:\users\ernes\anaconda3\lib\site-packages (from virtualenv) (3.12.0)
# created virtual environment CPython3.9.7.final.0-64 in 848ms
#   creator CPython3Windows(dest=C:\Users\ernes\OneDrive\Mokslai\SGT- Final Project\Data_Job_Market_Analysis_LV\myenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=C:\Users\ernes\AppData\Local\pypa\virtualenv)
#     added seed packages: pip==23.1.2, setuptools==67.7.2, wheel==0.40.0
#   activators BashActivator,BatchActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !myenv\Scripts\activate.bat

# %% [markdown]
# ### 1. Data Collection

# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
import re

# %% [markdown]
# ### Latvian cv.lv

# %%
url = 'https://www.cv.lv/lv/search?limit=2000&offset=20&keywords%5B0%5D=data%20analyst&keywords%5B1%5D=data%20scientist&keywords%5B2%5D=data%20engineer&keywords%5B3%5D=machine%20learning&keywords%5B4%5D=analyst&keywords%5B5%5D=anal%C4%ABti%C4%B7is&keywords%5B6%5D=datu&keywords%5B7%5D=datu%20zin%C4%81tnieks&keywords%5B8%5D=big%20data%20analytics&sorting=EXPIRING&fuzzy=false&suitableForRefugees=false&isHourlySalary=false&isRemoteWork=false&isQuickApply=false'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
vacancy_items = soup.find_all("li", class_="jsx-1871295890 jsx-2661613696 vacancies-list__item false")

# %%
vacancies = []
for item in vacancy_items:
    title = item.find("span", class_="jsx-1401030249 vacancy-item__title").text.strip()
    vacancy_item = item.find('a', {'class': 'vacancy-item'})
    vacancy_url = vacancy_item.get('href')
    end_date = item.find("span", class_="jsx-1401030249 vacancy-item__expiry").text.strip()
                                
    location = item.find("span", class_="jsx-1401030249 vacancy-item__locations").text.strip()
    salary = item.find("span", class_="jsx-1401030249 vacancy-item__salary-label")
    if salary is not None:
        salary = salary.text.strip()
    
    info_secondary = item.find('div', {'class': 'vacancy-item__info-secondary'})
    info_secondary_text = info_secondary.get_text()
    
    time_patterns = '(dien(a|s)|stund(a|s)|mēne(ši|sis)|sekund(e|es)|minūt(es|e))'
    pattern = f'Publicēts pirms (\d+) {time_patterns}|Atjaunināts pirms (\d+) {time_patterns}'
    match = re.search(pattern, info_secondary_text)
    published = match.group(0)
    
    p=1
    for a_tag in item.find_all('a', {'class': 'jsx-1401030249'}):
        p=p+1
        if p==3:
            company_name = a_tag.text
            company_url = a_tag['href']
        
      
    vacancies.append({
        "Title": title,
        "Vacancy URL" : vacancy_url,
        "Company name": company_name,
        "Company URL" :company_url,
        "Location": location,
        "Published": published,
        "End_date" : end_date, 
        "Salary": salary
    })

df = pd.DataFrame(vacancies)

# %% [markdown]
# ### Lithuanian cv.lt

# %%
vacancies_lt = []

for page in range(1, 10): # Change the range according to the number of pages you want to scrape
    url_lt = f"https://www.cv.lt/darbo-paieska/data?page={page}&texts=data"
    response = requests.get(url_lt)
    soup = BeautifulSoup(response.content, "html.parser")
    vacancy_items = soup.select(".job-wr")

    for item in vacancy_items:
        title = item.find("button", class_="title").text.strip()
        vacancy_item= soup.select_one('.job-wr')
        vacancy_url = vacancy_item['href']
        company_name = item.find("span", {"class": "company"}).find("button").text.strip()

        # for Lithuanian website, company url is not available, leaving for merging purposes
        company_url = "NaN"

        location = item.find("span", {"class": "company"}).find("span").text.strip()
        published = item.select_one(".time span").text

        # for Lithuanian website, expiry date is not available, leaving for merging purposes
        end_date = "NaN"

        salary = item.find("span", {"class": "salary"})
        if salary is not None:
            salary = salary.text.strip()
        else:
            salary='NaN'

        vacancies_lt.append({
                "Title": title,
                "Vacancy URL": vacancy_url,
                "Company name": company_name,
                "Company URL": company_url,
                "Location": location,
                "Published": published,
                "End_date": end_date,
                "Salary": salary,
            })

df_lt = pd.DataFrame(vacancies_lt)

# %% [markdown]
# ### 3. Data Cleaning

# %% [markdown]
# ### cv.lv

# %%
cv_lv_link = r'https://www.cv.lv'
df['Vacancy URL'] = cv_lv_link + df['Vacancy URL']
df['Company URL'] = cv_lv_link + df['Company URL']

# %%
df['End_date'] = df['End_date'].str.replace('Beidzas: ', '')

# %%
df['Location'] = df['Location'].str.replace('—', '')
# split Location column into City, Region, Country
splitting = lambda x: pd.Series([i for i in reversed(x.split(','))])
df[['Country', 'Region', 'City']] = df['Location'].apply(splitting)

# Remove the original Location column
df.drop('Location', axis=1, inplace=True)

# %%
df
# Out:
#                                                   Title  \
# 0                Customer Communication Project Manager
# 1                   Personāla attīstības speciālists/-e
# 2         GRAUDU PIRMAPSTRĀDES KOMPLEKSA DARBINIEKS-/CE
# 3                         C++ SOFTWARE ENGINEER - UI/UX
# 4     Informāciju sistēmu testētājs/-a (Middle QA En...
# ...                                                 ...
# 1001                                      Test Engineer
# 1002                               Senior Test Engineer
# 1003                                   Security Manager
# 1004  Automatizācijas sistēmu inženieris/ Vadošais a...
# 1005  Projektu vadītājs Zinātniskā institūta Izglītī...
#
#                                             Vacancy URL  \
# 0     https://www.cv.lv/lv/vacancy/992818/luminor-ba...
# 1     https://www.cv.lv/lv/vacancy/985020/latvijas-d...
# 2     https://www.cv.lv/lv/vacancy/985019/vaks-koope...
# 3     https://www.cv.lv/lv/vacancy/984816/ubiquiti-l...
# 4     https://www.cv.lv/lv/vacancy/984685/workingday...
# ...                                                 ...
# 1001  https://www.cv.lv/lv/vacancy/993940/visma/test...
# 1002  https://www.cv.lv/lv/vacancy/995138/visma/seni...
# 1003  https://www.cv.lv/lv/vacancy/987624/visma/secu...
# 1004  https://www.cv.lv/lv/vacancy/992319/belam-riga...
# 1005  https://www.cv.lv/lv/vacancy/926371/paula-stra...
#
#                                         Company name  \
# 0                   Luminor Bank AS Latvijas filiāle
# 1                            Latvijas dzelzceļš, VAS
# 2                        VAKS KOOPERATĪVĀ SABIEDRĪBA
# 3                             Ubiquiti (Latvia) SIA
# 4                                  WorkingDay Latvia
# ...                                              ...
# 1001                                           VISMA
# 1002                                           VISMA
# 1003                                           VISMA
# 1004                                Belam - Riga SIA
# 1005  Paula Stradiņa Klīniskā universitātes slimnīca
#
#                                             Company URL  \
# 0     https://www.cv.lv/lv/search/employer/luminor-b...
# 1     https://www.cv.lv/lv/search/employer/latvijas-...
# 2     https://www.cv.lv/lv/search/employer/vaks-koop...
# 3     https://www.cv.lv/lv/search/employer/ubiquiti-...
# 4     https://www.cv.lv/lv/search/employer/workingda...
# ...                                                 ...
# 1001  https://www.cv.lv/lv/search/employer/visma?emp...
# 1002  https://www.cv.lv/lv/search/employer/visma?emp...
# 1003  https://www.cv.lv/lv/search/employer/visma?emp...
# 1004  https://www.cv.lv/lv/search/employer/belam-rig...
# 1005  https://www.cv.lv/lv/search/employer/paula-str...
#
#                         Published    End_date         Salary   Country  \
# 0        Publicēts pirms 15 diena  13.05.2023  € 1940 – 2430   Latvija
# 1       Atjaunināts pirms 2 diena  13.05.2023  € 1100 – 1500   Latvija
# 2       Atjaunināts pirms 2 diena  13.05.2023         € 1300   Latvija
# 3     Atjaunināts pirms 17 stunda  13.05.2023  € 3000 – 7000   Latvija
# 4       Publicēts pirms 1 mēnesis  13.05.2023  € 2700 – 3500   Latvija
# ...                           ...         ...            ...       ...
# 1001     Publicēts pirms 11 diena  30.06.2023  € 2000 – 3000   Latvija
# 1002      Publicēts pirms 9 diena  30.06.2023  € 2400 – 3000   Latvija
# 1003     Publicēts pirms 25 diena  30.06.2023  € 3500 – 4500   Latvija
# 1004    Atjaunināts pirms 2 diena  27.07.2023         € 2000   Latvija
# 1005     Publicēts pirms 5 mēneši  21.12.2023         € 1350   Latvija
#
#                 Region      City
# 0         Rīgas rajons      Rīga
# 1         Rīgas rajons      Rīga
# 2      Jelgavas rajons   Jelgava
# 3         Rīgas rajons      Rīga
# 4         Rīgas rajons      Rīga
# ...                ...       ...
# 1001      Rīgas rajons      Rīga
# 1002      Rīgas rajons      Rīga
# 1003      Rīgas rajons      Rīga
# 1004      Rīgas rajons      Rīga
# 1005      Rīgas rajons      Rīga
#
# [1006 rows x 10 columns]

# %%
# Remove the euro sign
df['Salary'] = df['Salary'].str.replace('€', '').str.strip()


# Check the format of each entry and apply the corresponding operation
df[['Salary Range min', 'Salary Range max']] = df['Salary'].str.split('–', n=1, expand=True)

# %%
df['Salary Range min'] = df['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
df['Salary Range max'] = df['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)
# Out:
# C:\Users\ernes\AppData\Local\Temp/ipykernel_21952/1641069593.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Range min'] = df['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
# C:\Users\ernes\AppData\Local\Temp/ipykernel_21952/1641069593.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Range max'] = df['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)

# %%
for i in df.index:
    if pd.notna(df['Salary'][i]) and isinstance(df['Salary'][i], str) and '/st.' in df['Salary'][i]:
        if pd.notna(df['Salary Range min'][i]) and pd.notna(df['Salary Range max'][i]):
            df.loc[i, ['Salary Range min', 'Salary Range max']] *= 21.62 * 8

# %%
# Round the values to 2 decimal places
df['Salary Range min'] = df['Salary Range min'].round(2)
df['Salary Range max'] = df['Salary Range max'].round(2)

# %%
# remove the original Salary column
df.drop('Salary', axis=1, inplace=True)

# %%
import re
from datetime import datetime, timedelta

def get_date_from_string(s):
    if "dien" in s:
        days_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=days_ago)).strftime('%d.%m.%Y')
    elif "mēnesi" in s:
        months_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=months_ago*30)).strftime('%d.%m.%Y')
    elif "seku" in s or "min" in s or "stund" in s:
        return datetime.now().strftime('%d.%m.%Y')

# Apply the function to the column 'Published'
df['Published'] = df['Published'].apply(get_date_from_string)

# %% [markdown]
# ### cv.lt

# %%
# Adding beginning for vacancy url to show full link
cv_lt_link = r'https://www.cv.lt'
df_lt['Vacancy URL'] = cv_lt_link + df_lt['Vacancy URL']

# %%
# split Location field, if more than one city- to show as 'Various'
df_lt['Location'] = df_lt['Location'].apply(lambda x: 'Various' if isinstance(x, str) and ',' in x else x)

# %%
# Replace Location field 'Kitas' to 'Other' 
df_lt['Location'] = df_lt['Location'].str.replace('Kitas', 'Other').str.strip()

# %%
# Adding columns to match LV formating for location

Country='Lithuania'
df_lt.insert(loc=df_lt.columns.get_loc('End_date') + 2, column='Country', value=Country)
df_lt.insert(loc=df_lt.columns.get_loc('End_date')+3,column='Region', value='Nan')
df_lt.insert(loc=df_lt.columns.get_loc('End_date')+4,column='City', value=df_lt['Location'])


# Remove the original Location column
df_lt.drop('Location', axis=1, inplace=True)

# %%
# Cleaning Salary field, if it is showing different value than salary amount, to remove and show it as 0
def clean_salary(salary):
    if salary.startswith("Pareiginės "):
        return 'NaN
    else:
        return salary
    
df_lt["Salary"] = df_lt["Salary"].apply(clean_salary)

# %%
# Remove the euro sign 
df_lt['Salary'] = df_lt['Salary'].str.replace('€', '').str.strip()

# Remove the 'Nuo..' word
df_lt['Salary'] = df_lt['Salary'].str.replace('Nuo', '').str.strip()

# Remove the dot as a thousands separator
df_lt['Salary'] = df_lt['Salary'].str.replace('.', '').str.strip()
# Out:
# C:\Users\ernes\AppData\Local\Temp/ipykernel_21952/1120974158.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_lt['Salary'] = df_lt['Salary'].str.replace('.', '').str.strip()

# %%
# Spliting Salary field into two columns
df_lt[['Salary Range min', 'Salary Range max']] = df_lt['Salary'].str.extract(r'^(.*?)(?:-(.*))?$')

# %%
df_lt['Salary Range min'] = df_lt['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
df_lt['Salary Range max'] = df_lt['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)
# Out:
# C:\Users\ernes\AppData\Local\Temp/ipykernel_21952/35191948.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_lt['Salary Range min'] = df_lt['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
# C:\Users\ernes\AppData\Local\Temp/ipykernel_21952/35191948.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_lt['Salary Range max'] = df_lt['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)

# %%
# Round the values to 2 decimal places
df_lt['Salary Range min'] = df_lt['Salary Range min'].round(2)
df_lt['Salary Range max'] = df_lt['Salary Range max'].round(2)

# %%
# remove the original Salary column
df_lt.drop('Salary', axis=1, inplace=True)

# %%
# Formating job posting to show date instead of 'Before X days/months' etc.

import re
from datetime import datetime, timedelta

def get_date_from_string(s):
    if "d." in s:
        days_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=days_ago)).strftime('%d.%m.%Y')
    elif "mėn." in s:
        months_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=months_ago*30)).strftime('%d.%m.%Y')
    elif "val." in s or "min" in s:
        return datetime.now().strftime('%d.%m.%Y')

# Apply the function to the column 'Published'
df_lt['Published'] = df_lt['Published'].apply(get_date_from_string)

# %%
# Merging both dataframes into one
full_df = pd.concat([df, df_lt], ignore_index=True)

# %%
full_df
# Out:
#                                                   Title  \
# 0                Customer Communication Project Manager
# 1                   Personāla attīstības speciālists/-e
# 2         GRAUDU PIRMAPSTRĀDES KOMPLEKSA DARBINIEKS-/CE
# 3                         C++ SOFTWARE ENGINEER - UI/UX
# 4     Informāciju sistēmu testētājs/-a (Middle QA En...
# ...                                                 ...
# 1181                     Viešųjų pirkimų koordinatorius
# 1182  Resocializacijos skyriaus Vyriausiasis sociali...
# 1183  Projektų įgyvendinimo ir priežiūros skyriaus v...
# 1184  7-osios personalo administravimo grupės Person...
# 1185  3-iosios personalo administravimo grupės Perso...
#
#                                             Vacancy URL  \
# 0     https://www.cv.lv/lv/vacancy/992818/luminor-ba...
# 1     https://www.cv.lv/lv/vacancy/985020/latvijas-d...
# 2     https://www.cv.lv/lv/vacancy/985019/vaks-koope...
# 3     https://www.cv.lv/lv/vacancy/984816/ubiquiti-l...
# 4     https://www.cv.lv/lv/vacancy/984685/workingday...
# ...                                                 ...
# 1181  https://www.cv.lt/valstybes-tarnyba/komunikaci...
# 1182  https://www.cv.lt/valstybes-tarnyba/komunikaci...
# 1183  https://www.cv.lt/valstybes-tarnyba/komunikaci...
# 1184  https://www.cv.lt/valstybes-tarnyba/komunikaci...
# 1185  https://www.cv.lt/valstybes-tarnyba/komunikaci...
#
#                                            Company name  \
# 0                      Luminor Bank AS Latvijas filiāle
# 1                               Latvijas dzelzceļš, VAS
# 2                           VAKS KOOPERATĪVĀ SABIEDRĪBA
# 3                                Ubiquiti (Latvia) SIA
# 4                                     WorkingDay Latvia
# ...                                                 ...
# 1181                           Lietuvos kultūros taryba
# 1182                          Lietuvos kalėjimų tarnyba
# 1183  Lietuvos Respublikos aplinkos ministerijos Apl...
# 1184             Nacionalinis bendrųjų funkcijų centras
# 1185             Nacionalinis bendrųjų funkcijų centras
#
#                                             Company URL   Published  \
# 0     https://www.cv.lv/lv/search/employer/luminor-b...  28.04.2023
# 1     https://www.cv.lv/lv/search/employer/latvijas-...  11.05.2023
# 2     https://www.cv.lv/lv/search/employer/vaks-koop...  11.05.2023
# 3     https://www.cv.lv/lv/search/employer/ubiquiti-...  13.05.2023
# 4     https://www.cv.lv/lv/search/employer/workingda...  13.04.2023
# ...                                                 ...         ...
# 1181                                                Nan  09.05.2023
# 1182                                                Nan  09.05.2023
# 1183                                                Nan  11.05.2023
# 1184                                                Nan  10.05.2023
# 1185                                                Nan  09.05.2023
#
#         End_date    Country            Region      City  Salary Range min  \
# 0     13.05.2023    Latvija      Rīgas rajons      Rīga            1940.0
# 1     13.05.2023    Latvija      Rīgas rajons      Rīga            1100.0
# 2     13.05.2023    Latvija   Jelgavas rajons   Jelgava            1300.0
# 3     13.05.2023    Latvija      Rīgas rajons      Rīga            3000.0
# 4     13.05.2023    Latvija      Rīgas rajons      Rīga            2700.0
# ...          ...        ...               ...       ...               ...
# 1181         Nan  Lithuania               Nan   Vilnius               NaN
# 1182         Nan  Lithuania               Nan   Vilnius               NaN
# 1183         Nan  Lithuania               Nan   Vilnius               0.0
# 1184         Nan  Lithuania               Nan     Other               NaN
# 1185         Nan  Lithuania               Nan     Other               NaN
#
#       Salary Range max
# 0               2430.0
# 1               1500.0
# 2                  NaN
# 3               7000.0
# 4               3500.0
# ...                ...
# 1181               NaN
# 1182               NaN
# 1183               0.0
# 1184               NaN
# 1185               NaN
#
# [1186 rows x 11 columns]

# %% [markdown]
# ### 4. Data Filtering

# %%
filtered_df = full_df[full_df['Title'].str.contains('anal|dat', case=False)]

# %%
filtered_df
# Out:
#                                                   Title  \
# 10                          Middle/Senior Data Engineer
# 15                              Data Protection Officer
# 20    HR DATU APSTRĀDES SPECIĀLISTS/-E AR VĀCU VALOD...
# 31                                        Data Engineer
# 33            DATU PĀRVALDĪBAS UN PROJEKTU KOORDINATORS
# ...                                                 ...
# 1119    Business Analyst in Capital Exposure Management
# 1120    Business Analyst in Capital Exposure Management
# 1160  Viešųjų finansų sistemos valdymo grupės finans...
# 1168  Ekonominės analizės skyriaus vyriausiasis spec...
# 1173  Finansų politikos departamento Fiskalinės vald...
#
#                                             Vacancy URL  \
# 10    https://www.cv.lv/lv/vacancy/985446/it-camp/mi...
# 15    https://www.cv.lv/lv/vacancy/985792/via-sms-gr...
# 20    https://www.cv.lv/lv/vacancy/985581/cv-online-...
# 31    https://www.cv.lv/lv/vacancy/991049/luminor-ba...
# 33    https://www.cv.lv/lv/vacancy/988313/ergo-life-...
# ...                                                 ...
# 1119  https://www.cv.lt/administravimo-darbai/admini...
# 1120  https://www.cv.lt/administravimo-darbai/admini...
# 1160  https://www.cv.lt/teises-darbai/jaunesnysis-mo...
# 1168  https://www.cv.lt/valstybes-tarnyba/komunikaci...
# 1173  https://www.cv.lt/valstybes-tarnyba/komunikaci...
#
#                                    Company name  \
# 10                                      IT Camp
# 15                                VIA SMS Group
# 20                        CV-Online Recruitment
# 31             Luminor Bank AS Latvijas filiāle
# 33      ERGO Life Insurance SE Latvijas filiāle
# ...                                         ...
# 1119          Danske Bank A/S Lietuvos filialas
# 1120          Danske Bank A/S Lietuvos filialas
# 1160   Lietuvos Respublikos finansų ministerija
# 1168  Valstybinė energetikos reguliavimo taryba
# 1173   Lietuvos Respublikos finansų ministerija
#
#                                             Company URL   Published  \
# 10    https://www.cv.lv/lv/search/employer/it-camp?e...  14.04.2023
# 15    https://www.cv.lv/lv/search/employer/via-sms-g...  14.04.2023
# 20    https://www.cv.lv/lv/search/employer/cv-online...  13.05.2023
# 31    https://www.cv.lv/lv/search/employer/luminor-b...  25.04.2023
# 33    https://www.cv.lv/lv/search/employer/ergo-life...  11.05.2023
# ...                                                 ...         ...
# 1119                                                Nan  08.05.2023
# 1120                                                Nan  05.05.2023
# 1160                                                Nan  11.05.2023
# 1168                                                Nan  04.05.2023
# 1173                                                Nan  08.05.2023
#
#         End_date    Country         Region     City  Salary Range min  \
# 10    14.05.2023    Latvija   Rīgas rajons     Rīga            2900.0
# 15    14.05.2023    Latvija   Rīgas rajons     Rīga            2000.0
# 20    14.05.2023    Latvija   Rīgas rajons     Rīga            1600.0
# 31    14.05.2023    Latvija   Rīgas rajons     Rīga            1850.0
# 33    14.05.2023    Latvija   Rīgas rajons     Rīga            1200.0
# ...          ...        ...            ...      ...               ...
# 1119         Nan  Lithuania            Nan  Vilnius            2680.0
# 1120         Nan  Lithuania            Nan  Vilnius            2680.0
# 1160         Nan  Lithuania            Nan  Vilnius               NaN
# 1168         Nan  Lithuania            Nan    Other               NaN
# 1173         Nan  Lithuania            Nan  Vilnius               NaN
#
#       Salary Range max
# 10              5000.0
# 15              3000.0
# 20                 NaN
# 31              3400.0
# 33              1500.0
# ...                ...
# 1119            4020.0
# 1120            4020.0
# 1160               NaN
# 1168               NaN
# 1173               NaN
#
# [205 rows x 11 columns]

# %% [markdown]
# ### 5. SQLite Database

# %%
import sqlite3
import pandas as pd

# create a connection to the database
conn = sqlite3.connect('Job_postings_CV.db')

# save the DataFrame to the database
filtered_df.to_sql('alldata', conn)

# close the connection
conn.close()
# Out:
# C:\Users\ernes\anaconda3\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(
