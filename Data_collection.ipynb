# %% [markdown]
# # Analysis of Data Job Market in Latvia
# ## Data Collection and preparation

# %% [markdown]
# ### 0.Setting up Virtual Environment

# %%
# !pip install virtualenv
# !virtualenv myenv
# Out:
# Requirement already satisfied: virtualenv in c:\users\inese_\anaconda3\lib\site-packages (20.23.0)
# Requirement already satisfied: filelock<4,>=3.11 in c:\users\inese_\anaconda3\lib\site-packages (from virtualenv) (3.12.0)
# Requirement already satisfied: platformdirs<4,>=3.2 in c:\users\inese_\anaconda3\lib\site-packages (from virtualenv) (3.5.0)
# Requirement already satisfied: distlib<1,>=0.3.6 in c:\users\inese_\anaconda3\lib\site-packages (from virtualenv) (0.3.6)
# created virtual environment CPython3.8.8.final.0-64 in 6110ms
#   creator CPython3Windows(dest=C:\Users\Inese_\Desktop\sgt_project\myenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=C:\Users\Inese_\AppData\Local\pypa\virtualenv)
#     added seed packages: pip==23.1.2, setuptools==67.7.2, wheel==0.40.0
#   activators BashActivator,BatchActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !myenv\Scripts\activate.bat

# %% [markdown]
# ### 1. Data Collection

# %%
import requests
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
import re

# %%
url = 'https://www.cv.lv/lv/search?limit=2000&offset=20&keywords%5B0%5D=data%20analyst&keywords%5B1%5D=data%20scientist&keywords%5B2%5D=data%20engineer&keywords%5B3%5D=machine%20learning&keywords%5B4%5D=analyst&keywords%5B5%5D=anal%C4%ABti%C4%B7is&keywords%5B6%5D=datu&keywords%5B7%5D=datu%20zin%C4%81tnieks&keywords%5B8%5D=big%20data%20analytics&sorting=EXPIRING&fuzzy=false&suitableForRefugees=false&isHourlySalary=false&isRemoteWork=false&isQuickApply=false'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
vacancy_items = soup.find_all("li", class_="jsx-1871295890 jsx-2661613696 vacancies-list__item false")

# %%
vacancies = []
for item in vacancy_items:
    title = item.find("span", class_="jsx-1401030249 vacancy-item__title").text.strip()
    vacancy_item = item.find('a', {'class': 'vacancy-item'})
    vacancy_url = vacancy_item.get('href')
    end_date = item.find("span", class_="jsx-1401030249 vacancy-item__expiry").text.strip()
                                
    location = item.find("span", class_="jsx-1401030249 vacancy-item__locations").text.strip()
    salary = item.find("span", class_="jsx-1401030249 vacancy-item__salary-label")
    if salary is not None:
        salary = salary.text.strip()
    
    info_secondary = item.find('div', {'class': 'vacancy-item__info-secondary'})
    info_secondary_text = info_secondary.get_text()
    
    time_patterns = '(dien(a|s)|stund(a|s)|mēne(ši|sis)|sekund(e|es)|minūt(es|e))'
    pattern = f'Publicēts pirms (\d+) {time_patterns}|Atjaunināts pirms (\d+) {time_patterns}'
    match = re.search(pattern, info_secondary_text)
    published = match.group(0)
    
    p=1
    for a_tag in item.find_all('a', {'class': 'jsx-1401030249'}):
        p=p+1
        if p==3:
            company_name = a_tag.text
            company_url = a_tag['href']
        
      
    vacancies.append({
        "Title": title,
        "Vacancy URL" : vacancy_url,
        "Company name": company_name,
        "Company URL" :company_url,
        "Location": location,
        "Published": published,
        "End_date" : end_date, 
        "Salary": salary
    })

df = pd.DataFrame(vacancies)

# %% [markdown]
# ### 3. Data Cleaning

# %%
cv_lv_link = r'https://www.cv.lv'
df['Vacancy URL'] = cv_lv_link + df['Vacancy URL']
df['Company URL'] = cv_lv_link + df['Company URL']

# %%
df['End_date'] = df['End_date'].str.replace('Beidzas: ', '')

# %%
df['Location'] = df['Location'].str.replace('—', '')
# split Location column into City, Region, Country
splitting = lambda x: pd.Series([i for i in reversed(x.split(','))])
df[['Country', 'Region', 'City']] = df['Location'].apply(splitting)

# Remove the original Location column
df.drop('Location', axis=1, inplace=True)

# %%
df
# Out:
#                                                   Title  \
# 0                    IEKŠĒJĀS KOMUNIKĀCIJAS SPECIĀLISTS
# 1       Projektu vadītājs – jurists (uz noteiktu laiku)
# 2                  SABIEDRISKO ATTIECĪBU SPECIĀLISTS/-E
# 3     Sporta departamenta direktors (ierēdņa amats u...
# 4                                           CRM Analyst
# ...                                                 ...
# 998                                       Test Engineer
# 999                                Senior Test Engineer
# 1000                                   Security Manager
# 1001  Automatizācijas sistēmu inženieris/ Vadošais a...
# 1002  Projektu vadītājs Zinātniskā institūta Izglītī...
#
#                                             Vacancy URL  \
# 0     https://www.cv.lv/lv/vacancy/990508/rigas-namu...
# 1     https://www.cv.lv/lv/vacancy/988039/rigas-dome...
# 2     https://www.cv.lv/lv/vacancy/991836/centrala-f...
# 3     https://www.cv.lv/lv/vacancy/992246/lr-izgliti...
# 4     https://www.cv.lv/lv/vacancy/982718/sph-engine...
# ...                                                 ...
# 998   https://www.cv.lv/lv/vacancy/993940/visma/test...
# 999   https://www.cv.lv/lv/vacancy/995138/visma/seni...
# 1000  https://www.cv.lv/lv/vacancy/987624/visma/secu...
# 1001  https://www.cv.lv/lv/vacancy/992319/belam-riga...
# 1002  https://www.cv.lv/lv/vacancy/926371/paula-stra...
#
#                                         Company name  \
# 0                        Rīgas namu pārvaldnieks SIA
# 1                   Rīgas domes Īpašuma departaments
# 2         Centrālā finanšu un līgumu aģentūra (CFLA)
# 3               LR Izglītības un zinātnes ministrija
# 4                               SPH Engineering, SIA
# ...                                              ...
# 998                                            VISMA
# 999                                            VISMA
# 1000                                           VISMA
# 1001                                Belam - Riga SIA
# 1002  Paula Stradiņa Klīniskā universitātes slimnīca
#
#                                             Company URL  \
# 0     https://www.cv.lv/lv/search/employer/rigas-nam...
# 1     https://www.cv.lv/lv/search/employer/rigas-dom...
# 2     https://www.cv.lv/lv/search/employer/centrala-...
# 3     https://www.cv.lv/lv/search/employer/lr-izglit...
# 4     https://www.cv.lv/lv/search/employer/sph-engin...
# ...                                                 ...
# 998   https://www.cv.lv/lv/search/employer/visma?emp...
# 999   https://www.cv.lv/lv/search/employer/visma?emp...
# 1000  https://www.cv.lv/lv/search/employer/visma?emp...
# 1001  https://www.cv.lv/lv/search/employer/belam-rig...
# 1002  https://www.cv.lv/lv/search/employer/paula-str...
#
#                       Published    End_date         Salary   Country  \
# 0      Publicēts pirms 14 diena  09.05.2023         € 1500   Latvija
# 1      Publicēts pirms 20 diena  10.05.2023  € 1301 – 1700   Latvija
# 2      Publicēts pirms 12 diena  10.05.2023  € 1403 – 1584   Latvija
# 3     Atjaunināts pirms 5 diena  10.05.2023  € 2903 – 3226   Latvija
# 4     Atjaunināts pirms 6 diena  10.05.2023         € 2500   Latvija
# ...                         ...         ...            ...       ...
# 998     Publicēts pirms 6 diena  30.06.2023  € 2000 – 3000   Latvija
# 999     Publicēts pirms 4 diena  30.06.2023  € 2400 – 3000   Latvija
# 1000   Publicēts pirms 20 diena  30.06.2023  € 3500 – 4500   Latvija
# 1001  Atjaunināts pirms 5 diena  27.07.2023         € 2000   Latvija
# 1002   Publicēts pirms 5 mēneši  21.12.2023         € 1350   Latvija
#
#              Region     City
# 0      Rīgas rajons     Rīga
# 1      Rīgas rajons     Rīga
# 2      Rīgas rajons     Rīga
# 3      Rīgas rajons     Rīga
# 4      Rīgas rajons   Baloži
# ...             ...      ...
# 998    Rīgas rajons     Rīga
# 999    Rīgas rajons     Rīga
# 1000   Rīgas rajons     Rīga
# 1001   Rīgas rajons     Rīga
# 1002   Rīgas rajons     Rīga
#
# [1003 rows x 10 columns]

# %%
# Remove the euro sign
df['Salary'] = df['Salary'].str.replace('€', '').str.strip()


# Check the format of each entry and apply the corresponding operation
df[['Salary Range min', 'Salary Range max']] = df['Salary'].str.split('–', n=1, expand=True)

# %%
df['Salary Range min'] = df['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
df['Salary Range max'] = df['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)
# Out:
# <ipython-input-15-ca21c0923506>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Range min'] = df['Salary Range min'].str.replace('/st.', '').str.strip().astype(float)
# <ipython-input-15-ca21c0923506>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Salary Range max'] = df['Salary Range max'].str.replace('/st.', '').str.strip().astype(float)

# %%
for i in df.index:
    if pd.notna(df['Salary'][i]) and isinstance(df['Salary'][i], str) and '/st.' in df['Salary'][i]:
        if pd.notna(df['Salary Range min'][i]) and pd.notna(df['Salary Range max'][i]):
            df.loc[i, ['Salary Range min', 'Salary Range max']] *= 21.62 * 8

# %%
# Round the values to 2 decimal places
df['Salary Range min'] = df['Salary Range min'].round(2)
df['Salary Range max'] = df['Salary Range max'].round(2)

# %%
# remove the original Salary column
df.drop('Salary', axis=1, inplace=True)

# %%
import re
from datetime import datetime, timedelta

def get_date_from_string(s):
    if "dien" in s:
        days_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=days_ago)).strftime('%d.%m.%Y')
    elif "mēnesi" in s:
        months_ago = int(re.search(r'\d+', s).group())
        return (datetime.now() - timedelta(days=months_ago*30)).strftime('%d.%m.%Y')
    elif "seku" in s or "min" in s or "stund" in s:
        return datetime.now().strftime('%d.%m.%Y')

# Apply the function to the column 'Published'
df['Published'] = df['Published'].apply(get_date_from_string)

# %% [markdown]
# ### 4. Data Filtering

# %%
filtered_df = df[df['Title'].str.contains('anal|dat', case=False)]

# %%
filtered_df
# Out:
#                                                  Title  \
# 4                                          CRM Analyst
# 33                     Risk & Integrity System Analyst
# 38                                     DATU INŽENIERIS
# 40   REZERVES DAĻU UN NOLIKTAVAS KRĀJUMU DATU IEVAD...
# 49        Product Data Specialist (temporary contract)
# ..                                                 ...
# 984  VECĀKAIS ĶĪMIĶIS– ANALĪTIĶIS produktu attīstīb...
# 985                           Datu ievades operators/e
# 990                Biznesa analītikas (BI) eksperts/-e
# 991               QA analyst with Azerbaijani language
# 997                       Analītiķis/-e Piegādes tīklā
#
#                                            Vacancy URL  \
# 4    https://www.cv.lv/lv/vacancy/982718/sph-engine...
# 33   https://www.cv.lv/lv/vacancy/983555/evolution-...
# 38   https://www.cv.lv/lv/vacancy/983230/sia-aerone...
# 40   https://www.cv.lv/lv/vacancy/983494/arsenal-in...
# 49   https://www.cv.lv/lv/vacancy/992227/rimi-latvi...
# ..                                                 ...
# 984  https://www.cv.lv/lv/vacancy/997175/pharmidea-...
# 985  https://www.cv.lv/lv/vacancy/997217/konig-dist...
# 990  https://www.cv.lv/lv/vacancy/996869/elva-balti...
# 991  https://www.cv.lv/lv/vacancy/996973/lendiscore...
# 997  https://www.cv.lv/lv/vacancy/981781/maxima-lat...
#
#                 Company name  \
# 4       SPH Engineering, SIA
# 33      Evolution Latvia SIA
# 38   SIA Aerones Engineering
# 40    Arsenal Industrial SIA
# 49           RIMI Latvia SIA
# ..                       ...
# 984            PHARMIDEA SIA
# 985    König Distribution AS
# 990          Elva Baltic SIA
# 991           Lendiscore SIA
# 997       MAXIMA Latvija SIA
#
#                                            Company URL   Published  \
# 4    https://www.cv.lv/lv/search/employer/sph-engin...  03.05.2023
# 33   https://www.cv.lv/lv/search/employer/evolution...  09.05.2023
# 38   https://www.cv.lv/lv/search/employer/sia-aeron...  09.05.2023
# 40   https://www.cv.lv/lv/search/employer/arsenal-i...  09.05.2023
# 49   https://www.cv.lv/lv/search/employer/rimi-latv...  27.04.2023
# ..                                                 ...         ...
# 984  https://www.cv.lv/lv/search/employer/pharmidea...  09.05.2023
# 985  https://www.cv.lv/lv/search/employer/konig-dis...  09.05.2023
# 990  https://www.cv.lv/lv/search/employer/elva-balt...  09.05.2023
# 991  https://www.cv.lv/lv/search/employer/lendiscor...  09.05.2023
# 997  https://www.cv.lv/lv/search/employer/maxima-la...  09.05.2023
#
#        End_date   Country            Region      City  Salary Range min  \
# 4    10.05.2023   Latvija      Rīgas rajons    Baloži            2500.0
# 33   11.05.2023   Latvija      Rīgas rajons      Rīga            2500.0
# 38   11.05.2023   Latvija      Rīgas rajons      Rīga            2000.0
# 40   11.05.2023   Latvija      Rīgas rajons      Rīga            1000.0
# 49   11.05.2023   Latvija      Rīgas rajons      Rīga            1100.0
# ..          ...       ...               ...       ...               ...
# 984  09.06.2023   Latvija      Rīgas rajons    Olaine            1700.0
# 985  09.06.2023   Latvija   Liepājas rajons   Liepāja             900.0
# 990  09.06.2023   Latvija      Rīgas rajons      Rīga            2500.0
# 991  09.06.2023   Latvija      Rīgas rajons      Rīga             900.0
# 997  09.06.2023   Latvija      Rīgas rajons       NaN            1300.0
#
#      Salary Range max
# 4                 NaN
# 33                NaN
# 38             5000.0
# 40             1300.0
# 49             1350.0
# ..                ...
# 984               NaN
# 985               NaN
# 990            3500.0
# 991            1600.0
# 997               NaN
#
# [157 rows x 11 columns]

# %% [markdown]
# ### 5. SQLite Database

# %%
import sqlite3
import pandas as pd

# create a connection to the database
conn = sqlite3.connect('Job_postings_CVlv.db')

# save the DataFrame to the database
filtered_df.to_sql('alldata', conn)

# close the connection
conn.close()
