# %%
import sqlite3
import pandas as pd

# Connect to SQLite database
conn = sqlite3.connect('Job_postings_CV.db')

# Execute query and fetch results
query = "SELECT * FROM alldata"
df = pd.read_sql_query(query, conn)

# Close database connection
conn.close()

# %%
df['Job_id'] = df.index + 1

# %%
df_companies = df.drop_duplicates(subset=['Company name', 'Company URL']).reset_index(drop=True)
df_companies['company_id'] = df_companies.index + 1
df_companies = df_companies[['company_id', 'Company name', 'Company URL']]

# %%
df = df.merge(df_companies[['Company name', 'Company URL', 'company_id']], on=['Company name', 'Company URL'], how='left') # merge dataframes
df = df.rename(columns={'company_id': 'Company ID'}) # rename column
df = df.drop(['Company name', 'Company URL'], axis=1) # drop columns

# %%
df_companies
# Out:
#      company_id                               Company name  \
# 0             1                                    IT Camp
# 1             2                              VIA SMS Group
# 2             3                      CV-Online Recruitment
# 3             4           Luminor Bank AS Latvijas filiāle
# 4             5    ERGO Life Insurance SE Latvijas filiāle
# ..          ...                                        ...
# 112         113                         Ria Money Transfer
# 113         114             Baltic Virtual Assistants, UAB
# 114         115            Energijos skirstymo operatorius
# 115         116   Lietuvos Respublikos finansų ministerija
# 116         117  Valstybinė energetikos reguliavimo taryba
#
#                                            Company URL
# 0    https://www.cv.lv/lv/search/employer/it-camp?e...
# 1    https://www.cv.lv/lv/search/employer/via-sms-g...
# 2    https://www.cv.lv/lv/search/employer/cv-online...
# 3    https://www.cv.lv/lv/search/employer/luminor-b...
# 4    https://www.cv.lv/lv/search/employer/ergo-life...
# ..                                                 ...
# 112                                                Nan
# 113                                                Nan
# 114                                                Nan
# 115                                                Nan
# 116                                                Nan
#
# [117 rows x 3 columns]

# %%
df
# Out:
#      index                                              Title  \
# 0       10                        Middle/Senior Data Engineer
# 1       15                            Data Protection Officer
# 2       20  HR DATU APSTRĀDES SPECIĀLISTS/-E AR VĀCU VALOD...
# 3       31                                      Data Engineer
# 4       33          DATU PĀRVALDĪBAS UN PROJEKTU KOORDINATORS
# ..     ...                                                ...
# 200   1119    Business Analyst in Capital Exposure Management
# 201   1120    Business Analyst in Capital Exposure Management
# 202   1160  Viešųjų finansų sistemos valdymo grupės finans...
# 203   1168  Ekonominės analizės skyriaus vyriausiasis spec...
# 204   1173  Finansų politikos departamento Fiskalinės vald...
#
#                                            Vacancy URL   Published  \
# 0    https://www.cv.lv/lv/vacancy/985446/it-camp/mi...  14.04.2023
# 1    https://www.cv.lv/lv/vacancy/985792/via-sms-gr...  14.04.2023
# 2    https://www.cv.lv/lv/vacancy/985581/cv-online-...  13.05.2023
# 3    https://www.cv.lv/lv/vacancy/991049/luminor-ba...  25.04.2023
# 4    https://www.cv.lv/lv/vacancy/988313/ergo-life-...  11.05.2023
# ..                                                 ...         ...
# 200  https://www.cv.lt/administravimo-darbai/admini...  08.05.2023
# 201  https://www.cv.lt/administravimo-darbai/admini...  05.05.2023
# 202  https://www.cv.lt/teises-darbai/jaunesnysis-mo...  11.05.2023
# 203  https://www.cv.lt/valstybes-tarnyba/komunikaci...  04.05.2023
# 204  https://www.cv.lt/valstybes-tarnyba/komunikaci...  08.05.2023
#
#        End_date    Country         Region     City  Salary Range min  \
# 0    14.05.2023    Latvija   Rīgas rajons     Rīga            2900.0
# 1    14.05.2023    Latvija   Rīgas rajons     Rīga            2000.0
# 2    14.05.2023    Latvija   Rīgas rajons     Rīga            1600.0
# 3    14.05.2023    Latvija   Rīgas rajons     Rīga            1850.0
# 4    14.05.2023    Latvija   Rīgas rajons     Rīga            1200.0
# ..          ...        ...            ...      ...               ...
# 200         Nan  Lithuania            Nan  Vilnius            2680.0
# 201         Nan  Lithuania            Nan  Vilnius            2680.0
# 202         Nan  Lithuania            Nan  Vilnius               NaN
# 203         Nan  Lithuania            Nan    Other               NaN
# 204         Nan  Lithuania            Nan  Vilnius               NaN
#
#      Salary Range max  Job_id  Company ID
# 0              5000.0       1           1
# 1              3000.0       2           2
# 2                 NaN       3           3
# 3              3400.0       4           4
# 4              1500.0       5           5
# ..                ...     ...         ...
# 200            4020.0     201         110
# 201            4020.0     202         110
# 202               NaN     203         116
# 203               NaN     204         117
# 204               NaN     205         116
#
# [205 rows x 12 columns]

# %%
df_location = df.drop_duplicates(subset=['City', 'Region', 'Country']).reset_index(drop=True)
df_location['location_id'] = df_location.index + 1
df_location = df_location[['location_id', 'City', 'Region', 'Country']]

# %%
df_location
# Out:
#     location_id      City            Region      Country
# 0             1      Rīga      Rīgas rajons      Latvija
# 1             2      None      Rīgas rajons      Latvija
# 2             3      None              None      Lietuva
# 3             4      None              None      Latvija
# 4             5      None              None       Kenija
# 5             6    Olaine      Rīgas rajons      Latvija
# 6             7      None              None   Nīderlande
# 7             8    Baloži      Rīgas rajons      Latvija
# 8             9   Liepāja   Liepājas rajons      Latvija
# 9            10   Vilnius               Nan    Lithuania
# 10           11    Kaunas               Nan    Lithuania
# 11           12   Various               Nan    Lithuania
# 12           13     Other               Nan    Lithuania

# %%
df = df.merge(df_location[['City', 'Region', 'Country', 'location_id']], on=['City', 'Region','Country'], how='left') # merge dataframes
df = df.rename(columns={'location_id': 'Location ID'}) # rename column
df = df.drop(['City', 'Region', 'Country'], axis=1) # drop columns

# %%
df=df[['Job_id','Title', 'Vacancy URL','Company ID','Published','End_date','Salary Range min','Salary Range max','Location ID']]

# %%
df
# Out:
#      Job_id                                              Title  \
# 0         1                        Middle/Senior Data Engineer
# 1         2                            Data Protection Officer
# 2         3  HR DATU APSTRĀDES SPECIĀLISTS/-E AR VĀCU VALOD...
# 3         4                                      Data Engineer
# 4         5          DATU PĀRVALDĪBAS UN PROJEKTU KOORDINATORS
# ..      ...                                                ...
# 200     201    Business Analyst in Capital Exposure Management
# 201     202    Business Analyst in Capital Exposure Management
# 202     203  Viešųjų finansų sistemos valdymo grupės finans...
# 203     204  Ekonominės analizės skyriaus vyriausiasis spec...
# 204     205  Finansų politikos departamento Fiskalinės vald...
#
#                                            Vacancy URL  Company ID  \
# 0    https://www.cv.lv/lv/vacancy/985446/it-camp/mi...           1
# 1    https://www.cv.lv/lv/vacancy/985792/via-sms-gr...           2
# 2    https://www.cv.lv/lv/vacancy/985581/cv-online-...           3
# 3    https://www.cv.lv/lv/vacancy/991049/luminor-ba...           4
# 4    https://www.cv.lv/lv/vacancy/988313/ergo-life-...           5
# ..                                                 ...         ...
# 200  https://www.cv.lt/administravimo-darbai/admini...         110
# 201  https://www.cv.lt/administravimo-darbai/admini...         110
# 202  https://www.cv.lt/teises-darbai/jaunesnysis-mo...         116
# 203  https://www.cv.lt/valstybes-tarnyba/komunikaci...         117
# 204  https://www.cv.lt/valstybes-tarnyba/komunikaci...         116
#
#       Published    End_date  Salary Range min  Salary Range max  Location ID
# 0    14.04.2023  14.05.2023            2900.0            5000.0            1
# 1    14.04.2023  14.05.2023            2000.0            3000.0            1
# 2    13.05.2023  14.05.2023            1600.0               NaN            1
# 3    25.04.2023  14.05.2023            1850.0            3400.0            1
# 4    11.05.2023  14.05.2023            1200.0            1500.0            1
# ..          ...         ...               ...               ...          ...
# 200  08.05.2023         Nan            2680.0            4020.0           10
# 201  05.05.2023         Nan            2680.0            4020.0           10
# 202  11.05.2023         Nan               NaN               NaN           10
# 203  04.05.2023         Nan               NaN               NaN           13
# 204  08.05.2023         Nan               NaN               NaN           10
#
# [205 rows x 9 columns]

# %%
# connect to a SQLite database
conn = sqlite3.connect('Data_job_listings_CV_full.db')

# create a cursor object
c = conn.cursor()

# create a table for df
c.execute('''CREATE TABLE Job_listings
             (Job_id INTEGER PRIMARY KEY,
             Title TEXT,
             Vacancy_URL TEXT,
             Company_id INT,
             Date_published TEXT,
             End_Date TEXT,
             Salary_min_range REAL,
             Salary_max_range REAL,
             Location_id INT,
             FOREIGN KEY (Company_id) REFERENCES Companies(Company_id),
             FOREIGN KEY (Location_id) REFERENCES Locations(Location_id)
             
)''')

# create a table for df_locations
c.execute('''CREATE TABLE Locations
             (Location_id INTEGER PRIMARY KEY,
             City TEXT,
             Region TEXT,
             Country TEXT)''')


# create a table for df_companies
c.execute('''CREATE TABLE Companies
             (Company_id INTEGER PRIMARY KEY,
             Company_name TEXT,
             Company_URL TEXT)''')

# %%
# insert the data from df_locations into the df_locations table
df_location.to_sql('Locations', conn, if_exists='replace', index=False)

# insert the data from df_companies into the df_companies table
df_companies.to_sql('Companies', conn, if_exists='replace', index=False)

# insert the data from df into the df table
df.to_sql('Job_listings', conn, if_exists='replace', index=False)

# commit the changes and close the connection
conn.commit()
conn.close()
# Out:
# C:\Users\ernes\anaconda3\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(
