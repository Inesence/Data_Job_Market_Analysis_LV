# %%
import sqlite3
import pandas as pd

# Connect to SQLite database
conn = sqlite3.connect('Job_postings_CVlv.db')

# Execute query and fetch results
query = "SELECT * FROM alldata"
df = pd.read_sql_query(query, conn)

# Close database connection
conn.close()

# %%
df['Job_id'] = df.index + 1

# %%
df_companies = df.drop_duplicates(subset=['Company name', 'Company URL']).reset_index(drop=True)
df_companies['company_id'] = df_companies.index + 1
df_companies = df_companies[['company_id', 'Company name', 'Company URL']]

# %%
df = df.merge(df_companies[['Company name', 'Company URL', 'company_id']], on=['Company name', 'Company URL'], how='left') # merge dataframes
df = df.rename(columns={'company_id': 'Company ID'}) # rename column
df = df.drop(['Company name', 'Company URL'], axis=1) # drop columns

# %%
df_companies
# Out:
#     company_id             Company name  \
# 0            1     SPH Engineering, SIA
# 1            2     Evolution Latvia SIA
# 2            3  SIA Aerones Engineering
# 3            4   Arsenal Industrial SIA
# 4            5          RIMI Latvia SIA
# ..         ...                      ...
# 93          94             Aizdevums.lv
# 94          95               KRONUS SIA
# 95          96    König Distribution AS
# 96          97          Elva Baltic SIA
# 97          98           Lendiscore SIA
#
#                                           Company URL
# 0   https://www.cv.lv/lv/search/employer/sph-engin...
# 1   https://www.cv.lv/lv/search/employer/evolution...
# 2   https://www.cv.lv/lv/search/employer/sia-aeron...
# 3   https://www.cv.lv/lv/search/employer/arsenal-i...
# 4   https://www.cv.lv/lv/search/employer/rimi-latv...
# ..                                                ...
# 93  https://www.cv.lv/lv/search/employer/aizdevums...
# 94  https://www.cv.lv/lv/search/employer/kronus-si...
# 95  https://www.cv.lv/lv/search/employer/konig-dis...
# 96  https://www.cv.lv/lv/search/employer/elva-balt...
# 97  https://www.cv.lv/lv/search/employer/lendiscor...
#
# [98 rows x 3 columns]

# %%
df
# Out:
#      index                                              Title  \
# 0        4                                        CRM Analyst
# 1       33                    Risk & Integrity System Analyst
# 2       38                                    DATU INŽENIERIS
# 3       40  REZERVES DAĻU UN NOLIKTAVAS KRĀJUMU DATU IEVAD...
# 4       49       Product Data Specialist (temporary contract)
# ..     ...                                                ...
# 152    984  VECĀKAIS ĶĪMIĶIS– ANALĪTIĶIS produktu attīstīb...
# 153    985                           Datu ievades operators/e
# 154    990                Biznesa analītikas (BI) eksperts/-e
# 155    991               QA analyst with Azerbaijani language
# 156    997                       Analītiķis/-e Piegādes tīklā
#
#                                            Vacancy URL   Published  \
# 0    https://www.cv.lv/lv/vacancy/982718/sph-engine...  03.05.2023
# 1    https://www.cv.lv/lv/vacancy/983555/evolution-...  09.05.2023
# 2    https://www.cv.lv/lv/vacancy/983230/sia-aerone...  09.05.2023
# 3    https://www.cv.lv/lv/vacancy/983494/arsenal-in...  09.05.2023
# 4    https://www.cv.lv/lv/vacancy/992227/rimi-latvi...  27.04.2023
# ..                                                 ...         ...
# 152  https://www.cv.lv/lv/vacancy/997175/pharmidea-...  09.05.2023
# 153  https://www.cv.lv/lv/vacancy/997217/konig-dist...  09.05.2023
# 154  https://www.cv.lv/lv/vacancy/996869/elva-balti...  09.05.2023
# 155  https://www.cv.lv/lv/vacancy/996973/lendiscore...  09.05.2023
# 156  https://www.cv.lv/lv/vacancy/981781/maxima-lat...  09.05.2023
#
#        End_date  Salary Range min  Salary Range max  Company ID  Location ID  \
# 0    10.05.2023            2500.0               NaN           1            1
# 1    11.05.2023            2500.0               NaN           2            2
# 2    11.05.2023            2000.0            5000.0           3            2
# 3    11.05.2023            1000.0            1300.0           4            2
# 4    11.05.2023            1100.0            1350.0           5            2
# ..          ...               ...               ...         ...          ...
# 152  09.06.2023            1700.0               NaN          15            3
# 153  09.06.2023             900.0               NaN          96            9
# 154  09.06.2023            2500.0            3500.0          97            2
# 155  09.06.2023             900.0            1600.0          98            2
# 156  09.06.2023            1300.0               NaN          25            4
#
#      Job_id
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
# ..      ...
# 152     153
# 153     154
# 154     155
# 155     156
# 156     157
#
# [157 rows x 10 columns]

# %%
df_location = df.drop_duplicates(subset=['City', 'Region', 'Country']).reset_index(drop=True)
df_location['location_id'] = df_location.index + 1
df_location = df_location[['location_id', 'City', 'Region', 'Country']]

# %%
df_location
# Out:
#    location_id      City            Region      Country
# 0            1    Baloži      Rīgas rajons      Latvija
# 1            2      Rīga      Rīgas rajons      Latvija
# 2            3    Olaine      Rīgas rajons      Latvija
# 3            4      None      Rīgas rajons      Latvija
# 4            5      None              None      Lietuva
# 5            6      None              None      Latvija
# 6            7      None              None       Kenija
# 7            8      None              None   Nīderlande
# 8            9   Liepāja   Liepājas rajons      Latvija

# %%
df = df.merge(df_location[['City', 'Region', 'Country', 'location_id']], on=['City', 'Region','Country'], how='left') # merge dataframes
df = df.rename(columns={'location_id': 'Location ID'}) # rename column
df = df.drop(['City', 'Region', 'Country'], axis=1) # drop columns

# %%
df
# Out:
#      index                                              Title  \
# 0        4                                        CRM Analyst
# 1       33                    Risk & Integrity System Analyst
# 2       38                                    DATU INŽENIERIS
# 3       40  REZERVES DAĻU UN NOLIKTAVAS KRĀJUMU DATU IEVAD...
# 4       49       Product Data Specialist (temporary contract)
# ..     ...                                                ...
# 152    984  VECĀKAIS ĶĪMIĶIS– ANALĪTIĶIS produktu attīstīb...
# 153    985                           Datu ievades operators/e
# 154    990                Biznesa analītikas (BI) eksperts/-e
# 155    991               QA analyst with Azerbaijani language
# 156    997                       Analītiķis/-e Piegādes tīklā
#
#                                            Vacancy URL   Published  \
# 0    https://www.cv.lv/lv/vacancy/982718/sph-engine...  03.05.2023
# 1    https://www.cv.lv/lv/vacancy/983555/evolution-...  09.05.2023
# 2    https://www.cv.lv/lv/vacancy/983230/sia-aerone...  09.05.2023
# 3    https://www.cv.lv/lv/vacancy/983494/arsenal-in...  09.05.2023
# 4    https://www.cv.lv/lv/vacancy/992227/rimi-latvi...  27.04.2023
# ..                                                 ...         ...
# 152  https://www.cv.lv/lv/vacancy/997175/pharmidea-...  09.05.2023
# 153  https://www.cv.lv/lv/vacancy/997217/konig-dist...  09.05.2023
# 154  https://www.cv.lv/lv/vacancy/996869/elva-balti...  09.05.2023
# 155  https://www.cv.lv/lv/vacancy/996973/lendiscore...  09.05.2023
# 156  https://www.cv.lv/lv/vacancy/981781/maxima-lat...  09.05.2023
#
#        End_date  Salary Range min  Salary Range max  Company ID  Location ID  \
# 0    10.05.2023            2500.0               NaN           1            1
# 1    11.05.2023            2500.0               NaN           2            2
# 2    11.05.2023            2000.0            5000.0           3            2
# 3    11.05.2023            1000.0            1300.0           4            2
# 4    11.05.2023            1100.0            1350.0           5            2
# ..          ...               ...               ...         ...          ...
# 152  09.06.2023            1700.0               NaN          15            3
# 153  09.06.2023             900.0               NaN          96            9
# 154  09.06.2023            2500.0            3500.0          97            2
# 155  09.06.2023             900.0            1600.0          98            2
# 156  09.06.2023            1300.0               NaN          25            4
#
#      Job_id
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
# ..      ...
# 152     153
# 153     154
# 154     155
# 155     156
# 156     157
#
# [157 rows x 10 columns]

# %%
# connect to a SQLite database
conn = sqlite3.connect('Data_job_listings_CV_lv.db')

# create a cursor object
c = conn.cursor()

# create a table for df
c.execute('''CREATE TABLE job_listings
             (Job_id INTEGER PRIMARY KEY,
             Title TEXT,
             Vacancy_URL TEXT,
             Date_published 
             Company_id INTEGER,
             Location_id INTEGER,
             Description TEXT)''')

# create a table for df_locations
c.execute('''CREATE TABLE df_locations
             (Location_id INTEGER PRIMARY KEY,
             City TEXT,
             Region TEXT,
             Country TEXT)''')

# create a table for df_companies
c.execute('''CREATE TABLE df_companies
             (Company_id INTEGER PRIMARY KEY,
             Company_name TEXT,
             Company_URL TEXT)''')

# insert the data from df_locations into the df_locations table
df_locations.to_sql('df_locations', conn, if_exists='replace', index=False)

# insert the data from df_companies into the df_companies table
df_companies.to_sql('df_companies', conn, if_exists='replace', index=False)

# insert the data from df into the df table
df.to_sql('df', conn, if_exists='replace', index=False)

# commit the changes and close the connection
conn.commit()
conn.close()
