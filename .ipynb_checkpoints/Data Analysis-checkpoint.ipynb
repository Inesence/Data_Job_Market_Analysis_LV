# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## 0. Data import from the database

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('Data_job_listings_CV_lv.db')

# %%
query = '''
SELECT Job_listings.*, Companies.*, Locations.*
FROM Job_listings
LEFT JOIN Companies ON Job_listings.'Company ID'= Companies.Company_id
LEFT JOIN Locations ON Job_listings.'Location ID' = Locations.location_id
'''

# %%
df = pd.read_sql(query, conn)

# %%
df
# Out:
#      Job_id                                              Title  \
# 0         1                                        CRM Analyst
# 1         2                    Risk & Integrity System Analyst
# 2         3                                    DATU INŽENIERIS
# 3         4  REZERVES DAĻU UN NOLIKTAVAS KRĀJUMU DATU IEVAD...
# 4         5       Product Data Specialist (temporary contract)
# ..      ...                                                ...
# 152     153  VECĀKAIS ĶĪMIĶIS– ANALĪTIĶIS produktu attīstīb...
# 153     154                           Datu ievades operators/e
# 154     155                Biznesa analītikas (BI) eksperts/-e
# 155     156               QA analyst with Azerbaijani language
# 156     157                       Analītiķis/-e Piegādes tīklā
#
#                                            Vacancy URL  Company ID  \
# 0    https://www.cv.lv/lv/vacancy/982718/sph-engine...           1
# 1    https://www.cv.lv/lv/vacancy/983555/evolution-...           2
# 2    https://www.cv.lv/lv/vacancy/983230/sia-aerone...           3
# 3    https://www.cv.lv/lv/vacancy/983494/arsenal-in...           4
# 4    https://www.cv.lv/lv/vacancy/992227/rimi-latvi...           5
# ..                                                 ...         ...
# 152  https://www.cv.lv/lv/vacancy/997175/pharmidea-...          15
# 153  https://www.cv.lv/lv/vacancy/997217/konig-dist...          96
# 154  https://www.cv.lv/lv/vacancy/996869/elva-balti...          97
# 155  https://www.cv.lv/lv/vacancy/996973/lendiscore...          98
# 156  https://www.cv.lv/lv/vacancy/981781/maxima-lat...          25
#
#       Published    End_date  Salary Range min  Salary Range max  Location ID  \
# 0    03.05.2023  10.05.2023            2500.0               NaN            1
# 1    09.05.2023  11.05.2023            2500.0               NaN            2
# 2    09.05.2023  11.05.2023            2000.0            5000.0            2
# 3    09.05.2023  11.05.2023            1000.0            1300.0            2
# 4    27.04.2023  11.05.2023            1100.0            1350.0            2
# ..          ...         ...               ...               ...          ...
# 152  09.05.2023  09.06.2023            1700.0               NaN            3
# 153  09.05.2023  09.06.2023             900.0               NaN            9
# 154  09.05.2023  09.06.2023            2500.0            3500.0            2
# 155  09.05.2023  09.06.2023             900.0            1600.0            2
# 156  09.05.2023  09.06.2023            1300.0               NaN            4
#
#      company_id             Company name  \
# 0             1     SPH Engineering, SIA
# 1             2     Evolution Latvia SIA
# 2             3  SIA Aerones Engineering
# 3             4   Arsenal Industrial SIA
# 4             5          RIMI Latvia SIA
# ..          ...                      ...
# 152          15            PHARMIDEA SIA
# 153          96    König Distribution AS
# 154          97          Elva Baltic SIA
# 155          98           Lendiscore SIA
# 156          25       MAXIMA Latvija SIA
#
#                                            Company URL  location_id      City  \
# 0    https://www.cv.lv/lv/search/employer/sph-engin...            1    Baloži
# 1    https://www.cv.lv/lv/search/employer/evolution...            2      Rīga
# 2    https://www.cv.lv/lv/search/employer/sia-aeron...            2      Rīga
# 3    https://www.cv.lv/lv/search/employer/arsenal-i...            2      Rīga
# 4    https://www.cv.lv/lv/search/employer/rimi-latv...            2      Rīga
# ..                                                 ...          ...       ...
# 152  https://www.cv.lv/lv/search/employer/pharmidea...            3    Olaine
# 153  https://www.cv.lv/lv/search/employer/konig-dis...            9   Liepāja
# 154  https://www.cv.lv/lv/search/employer/elva-balt...            2      Rīga
# 155  https://www.cv.lv/lv/search/employer/lendiscor...            2      Rīga
# 156  https://www.cv.lv/lv/search/employer/maxima-la...            4      None
#
#                Region   Country  avg_salary
# 0        Rīgas rajons   Latvija      2500.0
# 1        Rīgas rajons   Latvija      2500.0
# 2        Rīgas rajons   Latvija      3500.0
# 3        Rīgas rajons   Latvija      1150.0
# 4        Rīgas rajons   Latvija      1225.0
# ..                ...       ...         ...
# 152      Rīgas rajons   Latvija      1700.0
# 153   Liepājas rajons   Latvija       900.0
# 154      Rīgas rajons   Latvija      3000.0
# 155      Rīgas rajons   Latvija      1250.0
# 156      Rīgas rajons   Latvija      1300.0
#
# [157 rows x 17 columns]

# %% [markdown]
# ## 1. Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns

# %% [markdown]
# ### 1.1 Salary distribution

# %%
df['avg_salary'] = df[['Salary Range min', 'Salary Range max']].mean(axis=1)

# %%
mean_salary = df['avg_salary'].mean()
std_salary = df['avg_salary'].std()

# %%
plt.hist(df['avg_salary'].dropna(), bins=10, alpha=0.5, color='blue')
plt.axvline(mean_salary, color='red', linestyle='dashed', linewidth=1)
plt.title('Salary Distribution')
plt.xlabel('Salary Range')
plt.ylabel('Number of Job Listings')
plt.show()

# %%
# Generate statistics table for average salary column
mean_salary = df['avg_salary'].mean()

# create a table with salary statistics
stats_table = pd.DataFrame({
    'Minimum Salary': df['avg_salary'].min(),
    'Maximum Salary': df['avg_salary'].max(),
    'Average Salary': mean_salary,
    'Median Salary': df['avg_salary'].median(),
    'Standard Deviation': df['avg_salary'].std()
}, index=['Statistics'])

# style the table for better formatting
stats_table = stats_table.style.set_table_styles([{
    'selector': 'th',
    'props': [
        ('background-color', 'lightgrey'),
        ('color', 'black'),
        ('font-weight', 'bold'),
        ('text-align', 'center'),
        ('border', '1px solid black'),
        ('padding', '5px')
    ]
}, {
    'selector': 'td',
    'props': [
        ('text-align', 'center'),
        ('border', '1px solid black'),
        ('padding', '5px')
    ]
}])

stats_table
# Out:
# <style  type="text/css" >
#     #T_a26e9_ th {
#           background-color: lightgrey;
#           color: black;
#           font-weight: bold;
#           text-align: center;
#           border: 1px solid black;
#           padding: 5px;
#     }    #T_a26e9_ td {
#           text-align: center;
#           border: 1px solid black;
#           padding: 5px;
#     }</style><table id="T_a26e9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Minimum Salary</th>        <th class="col_heading level0 col1" >Maximum Salary</th>        <th class="col_heading level0 col2" >Average Salary</th>        <th class="col_heading level0 col3" >Median Salary</th>        <th class="col_heading level0 col4" >Standard Deviation</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a26e9_level0_row0" class="row_heading level0 row0" >Statistics</th>
#                         <td id="T_a26e9_row0_col0" class="data row0 col0" >5.500000</td>
#                         <td id="T_a26e9_row0_col1" class="data row0 col1" >6150.000000</td>
#                         <td id="T_a26e9_row0_col2" class="data row0 col2" >2476.738471</td>
#                         <td id="T_a26e9_row0_col3" class="data row0 col3" >2500.000000</td>
#                         <td id="T_a26e9_row0_col4" class="data row0 col4" >1049.141464</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### 1.2 Job posting distribution by location

# %%
df_latvia = df[(df['Country'] == '\xa0Latvija') | (df['Country'] == ' Latvija')]

# %%
# group the data by city and count the number of jobs in each city
jobs_by_city = df_latvia.groupby('City')['Title'].count()

#define Seaborn color palette to use
colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(10,10)) # set figure size
#create pie chart
plt.pie(jobs_by_city, labels=jobs_by_city.index, colors = colors, autopct='%1.1f%%', textprops={'fontsize': 14})
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.3 End date

# %%
plt.figure(figsize=(40,10)) # set figure size
plt.hist(df['End_date'].dropna(), bins=100, alpha=0.5, color='blue')

plt.title('End Date Distribution', fontsize= 25)
plt.xlabel('Date Range',  fontsize= 25)
plt.ylabel('Number of Job Listings',  fontsize= 25)
plt.show()
